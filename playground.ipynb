# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times = np.arange(1,5)
datas = []
for t in times:
    data = np.loadtxt(f'/Users/calebpainter/Downloads/Classes/AM207/final_project/out-00{t}.dat')
    datas.append(data)

# %%
times = np.arange(1,5)
datas = []
for t in times:
    data = np.loadtxt(f'/Users/calebpainter/Downloads/Classes/AM207/final_project/out-{t}.dat')
    datas.append(data)

# %%
for data in datas:
    times = [x[0] for x in data]
    densities = [x[1] for x in data]

    plt.plot(times,densities)
    plt.xscale('log')
    plt.yscale('log')
